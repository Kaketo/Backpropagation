# %%
from network import Layer
from network import Network
from program_functions import data_read_classification
from program_functions import data_read_regression
from program_functions import plot_classification
from program_functions import plot_regression
from program_functions import plot_errors
import numpy as np
np.random.seed(seed = 0)

# %% [markdown]
# # Problem regresji

# %%
# Do pokazania że przy takim samym przedziale błąd jest bardzo niski
# Żeby dane testowe pochodziły z tego samego przedziału co dane treningowe
# x3 = x[3][(x[2] > min(x[0])) & (x[2] < max(x[0]))]
# x2 = x[2][(x[2] > min(x[0])) & (x[2] < max(x[0]))]
# x[2] = x2
# x[3] = x3

# %% [markdown]
# ## Funkcja liniowa
# Teoretycznie powinna wystarczyć jedna warstwa neuronów do przybliżenia takiej funkcji

# %%
x = data_read_regression('linear',100)
brain = Network(learning_rate = 0.001, momentum_rate = 0.7, iterations = 100)
brain.add(Layer(1,1,'sigmoid'))
brain.add(Layer(1,1,'linear'))
#errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %%
x = data_read_regression('linear',100)
brain = Network(learning_rate = 0.001, momentum_rate = 0.7, iterations = 100)
brain.add(Layer(1,15,'sigmoid'))
brain.add(Layer(15,10,'sigmoid'))
brain.add(Layer(10,1,'linear'))
#errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %% [markdown]
# ## Funckja aktywacji

# %%
x = data_read_regression('activation',100)
brain = Network(learning_rate = 0.001, momentum_rate = 0.7, iterations = 100)
brain.add(Layer(1,10,'sigmoid'))
brain.add(Layer(10,50,'sigmoid'))
brain.add(Layer(50,10,'sigmoid'))
brain.add(Layer(10,1,'linear'))
#errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %% [markdown]
# ## Funkcja kwadratowa (square function)
# Teoretycznie powinno wystarczyć 3 warstwy, druga powinna mieć minimum 2 neurony

# %%
x = data_read_regression('square',100)
brain = Network(learning_rate = 0.0001, momentum_rate = 0.2, iterations = 1000)
brain.add(Layer(1,20,'sigmoid'))
brain.add(Layer(20,10,'sigmoid'))
brain.add(Layer(10,1,'linear'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %% [markdown]
# ## Wielomian 3 stopnia (cube function)
# Teoretycznie powinny wystarczyć 3 warstwy, druga powinna mieć minimym 3 neurony

# %%
x = data_read_regression('cube',100)
brain = Network(learning_rate = 0.001, momentum_rate = 0.8, iterations = 100)
brain.add(Layer(1,30,'sigmoid'))
brain.add(Layer(30,15,'sigmoid'))
brain.add(Layer(15,1,'linear'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %% [markdown]
# ## Multimodal function
# Potrzeba wielu warstw i wielu neuronów, funkcja mocno skomplikowana

# %%
x = data_read_regression('multimodal',1000)
brain = Network(learning_rate = 0.001, momentum_rate = 0, iterations = 100)
brain.add(Layer(1,30,'sigmoid'))
brain.add(Layer(30,15,'sigmoid'))
brain.add(Layer(15,1,'linear'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_regression(brain, x)

# %% [markdown]
# # Problem klasyfikacji

# %% [markdown]
# ## Simple classification
# Prosty podział, nie potrzeba za wielu neuronów

# %%
x = data_read_classification('simple',100)
brain = Network(learning_rate = 0.1, momentum_rate = 0.8, iterations = 100)
brain.add(Layer(2,20,'sigmoid'))
brain.add(Layer(20,10,'sigmoid'))
brain.add(Layer(10,2,'sigmoid'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_classification(brain, x)

# %% [markdown]
# ## XOR
# Minimum 2 warstwy - problem nieliniowy

# %%
x = data_read_classification('xor',100)
brain = Network(learning_rate = 0.1, momentum_rate = 0.9, iterations = 100)
brain.add(Layer(2,20,'sigmoid'))
brain.add(Layer(20,10,'sigmoid'))
brain.add(Layer(10,2,'sigmoid'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_classification(brain, x)

# %% [markdown]
# ## Noisy XOR
# Minimum 2 warstwy - problem nieliniowy

# %%
x = data_read_classification('xor',100)
brain = Network(learning_rate = 0.1, momentum_rate = 0.8, iterations = 100)
brain.add(Layer(2,20,'sigmoid'))
brain.add(Layer(20,50,'sigmoid'))
brain.add(Layer(50,10,'sigmoid'))
brain.add(Layer(10,2,'sigmoid'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_classification(brain, x)

# %% [markdown]
# ## Three Gauss
# Skomplikowany problem - potrzeba wielu neuronów

# %%
x = data_read_classification('three_gauss',100)
brain = Network(learning_rate = 0.1, momentum_rate = 0.8, iterations = 100)
brain.add(Layer(2,20,'sigmoid'))
brain.add(Layer(20,10,'sigmoid'))
brain.add(Layer(10,3,'sigmoid'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_classification(brain, x)

# %% [markdown]
# ## Circles
# Potrzeba bardzo dużej ilości neuronów i warstw
# Warstw najlepiej tyle ile jest patternów na obrazku

# %%
x = data_read_classification('circles',100)
brain = Network(learning_rate = 0.1, momentum_rate = 0.8, iterations = 1000)
brain.add(Layer(2,10,'sigmoid'))
brain.add(Layer(10,100,'sigmoid'))
brain.add(Layer(100,50,'sigmoid'))
brain.add(Layer(50,4,'sigmoid'))
errors = brain.train_and_evaluate(x[0],x[1],x[2],x[3])
#errors = brain.train_mini_batch_and_evaluate(x[0],x[1],x[2],x[3],10)
plot_errors(errors)
plot_classification(brain, x)
